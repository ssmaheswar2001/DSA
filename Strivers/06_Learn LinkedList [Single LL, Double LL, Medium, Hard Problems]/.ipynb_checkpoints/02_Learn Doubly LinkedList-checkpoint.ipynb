# %% [markdown]
# # Array to DoubleLinkedList

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None
        
class DoubleLL:
    def __init__(self):
        self.head = None
    
    def constructDLL(self, arr):
        n = len(arr)
        
        self.head = Node(arr[0])
        current = self.head
        
        for i in range(1, n):
            newNode = Node(arr[i])
            current.next = newNode
            newNode.prev = current
            current = current.next
            
        return self.head
    
    def printDLL(self, head):
        current = head
        
        while current != None:
            print(current.data, end='<->')
            current = current.next
            
        print()
    
arr = [1, 2, 3, 4, 5]
dll = DoubleLL()
head = dll.constructDLL(arr)
dll.printDLL(head)
# Out:
# 1<->2<->3<->4<->5<->

# %% [markdown]
# # Deletion of Node in DoubleLinked List

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None
        
class DoubleLL:
    def __init__(self):
        self.head = None
    
    def constructDLL(self, arr):
        n = len(arr)
        
        self.head = Node(arr[0])
        current = self.head
        
        for i in range(1, n):
            newNode = Node(arr[i])
            current.next = newNode
            newNode.prev = current
            current = current.next
            
        return self.head
    
    def deleteHead(self, head):
        if head is None:
            return None
        if head.next is None:
            return None
        
        current = head
        head = current.next
        head.prev = None
        current.next = None
        return head
    
    def deleteTail(self, head):
        if head is None or head.next is None:
            return None
        
        current = head
        while current.next != None:
            current = current.next
        
        previousNode = current.prev
        current.prev = None
        previousNode.next = None
        return head
    
    def deleteKElement(self, head, k):
        if head == None:
            return None
        
        current = head
        count = 0
        while current != None:
            count += 1
            if count == k:
                break
            current = current.next
            
        if current.prev == None and current.next == None:
            return None
        if current.prev == None:
            return self.deleteHead(head)
        if current.next == None:
            return self.deleteTail(head)
        
        previousNode = current.prev
        nextNode = current.next
        
        previousNode.next = nextNode
        nextNode.prev = previousNode
        
        current.prev = None
        current.next = None
        return head
        
    
    def printDLL(self, head):
        current = head
        while current != None:
            print(current.data, end='<->')
            current = current.next
        print()
    
arr = [1, 3, 4]
dll = DoubleLL()
head = dll.constructDLL(arr)
dll.printDLL(head)
head = dll.deleteKElement(head, 3)
dll.printDLL(head)
# Out:
# 1<->3<->4<->
# 1<->3<->

# %% [markdown]
# # Insertion of Node in Double Linked List

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None
        
class DoubleLL:
    def __init__(self):
        self.head = None
    
    def constructDLL(self, arr):
        n = len(arr)
        
        self.head = Node(arr[0])
        current = self.head
        
        for i in range(1, n):
            newNode = Node(arr[i])
            current.next = newNode
            newNode.prev = current
            current = current.next
            
        return self.head
    
    def insertAtHead(self, head, data):
        newNode = Node(data)
        
        if head == None:
            head = NewNode
            return head
        
        head.prev = newNode
        newNode.next = head
        head = newNode
        return head
        
    def insertAtTail(self, head, data):
        newNode = Node(data)
        
        if head == None:
            head = newNode
            return head
        
        current = head
        while current.next != None:
            current = current.next
            
        current.next = newNode
        newNode.prev = current
        return head
    
    def insertBeforeKPosition(self, head, data, k):
        newNode = Node(data)
        if k == 1:
            return self.insertAtHead(head, data)
        
        current =  head
        count = 0
        while current != None:
            count += 1
            if count == k:
                break
            current = current.next
        
        previousNode = current.prev
        newNode.next = current
        newNode.prev = previousNode
        previousNode.next = newNode
        previousNode.prev = current
        return head
        
    def printDLL(self, head):
        current = head
        
        while current != None:
            print(current.data, end='<->')
            current = current.next
            
        print()
    
arr = [1, 2, 3, 4, 5]
dll = DoubleLL()
head = dll.constructDLL(arr)
dll.printDLL(head)
head = dll.insertBeforeKPosition(head, 7, 2)
dll.printDLL(head)
# Out:
# 1<->2<->3<->4<->5<->
# 1<->7<->2<->3<->4<->5<->

# %% [markdown]
# # Reverse A DLL

# %%
# Better Approach : Using Stack DS
# Time Complexity : O(N) + O(N)
# Space Complexity : O(N)

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None
        
class DoubleLL:
    def __init__(self):
        self.head = None
    
    def constructDLL(self, arr):
        n = len(arr)
        
        self.head = Node(arr[0])
        current = self.head
        
        for i in range(1, n):
            newNode = Node(arr[i])
            current.next = newNode
            newNode.prev = current
            current = current.next
            
        return self.head
    
    def reverseDLL(self, head):
        
        stack = []
        current = head
        
        while current != None:
            stack.append(current.data)
            current = current.next
        
        top = len(stack)-1
        current = head
        while current != None:
            current.data = stack[top]
            top -= 1
            current = current.next
        return head
    
    def printDLL(self, head):
        current = head
        
        while current != None:
            print(current.data, end='<->')
            current = current.next
            
        print()
    
arr = [1, 2, 3, 4, 5]
dll = DoubleLL()
head = dll.constructDLL(arr)
dll.printDLL(head)
head = dll.reverseDLL(head)
dll.printDLL(head)
# Out:
# 1<->2<->3<->4<->5<->
# 5<->4<->3<->2<->1<->

# %%
# Optimal Approach : 
# Time Complexity : O(N)
# Space Complexity : O(1)

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None
        
class DoubleLL:
    def __init__(self):
        self.head = None
    
    def constructDLL(self, arr):
        n = len(arr)
        
        self.head = Node(arr[0])
        current = self.head
        
        for i in range(1, n):
            newNode = Node(arr[i])
            current.next = newNode
            newNode.prev = current
            current = current.next
            
        return self.head
    
    def reverseDLL(self, head):
        if head == None or head.next == None:
            return head
        
        current = head
        while current != None:
            previousNode = current.prev
            current.prev = current.next
            current.next = previousNode
            current = current.prev 
        
        head = previousNode.prev
        return head
        
    
    def printDLL(self, head):
        current = head
        
        while current != None:
            print(current.data, end='<->')
            current = current.next
            
        print()
    
arr = [1, 2, 3, 4, 5]
dll = DoubleLL()
head = dll.constructDLL(arr)
dll.printDLL(head)
head = dll.reverseDLL(head)
dll.printDLL(head)
# Out:
# 1<->2<->3<->4<->5<->
# 5<->4<->3<->2<->1<->
